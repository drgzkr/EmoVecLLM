# %% [markdown]
# # 08 — Local vs global
#
# *(Describe what this notebook does.)*

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../src')

# from emovecllm.core import ...
# from analysis.figures import save_fig

# %% [markdown]
# ## Step 1
#
# *(To be implemented.)*
